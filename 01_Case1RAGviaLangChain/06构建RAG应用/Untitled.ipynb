# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    base_url='http://localhost:11434', 
    model='deepseek-r1:1.5b',
    # temperature = 0.8,
    # num_predict = 256,
    # other params ...
)

# messages = [
#     ("system", "You are a helpful translator. Translate the user sentence to French."),
#     ("human", "I love programming."),
# ]
llm.invoke("求解余弦")
# Out:
# AIMessage(content='<think>\n\n</think>\n\n要解决关于余弦的问题，通常需要明确具体的任务或方程。以下是一些常见的余弦相关问题及其解答：\n\n### 1. 计算已知角的余弦值\n**问题:** 已知角θ = 60°，求cosθ。\n**解答:**\n使用三角函数的定义：\n\\[ \\cos{60^\\circ} = \\frac{1}{2} \\]\n\n### 2. 解方程\n**问题:** 解方程：\\( 2\\cos{\\theta} + 3 = 5 \\)。\n**解答:**\n将方程化简：\n\\[ 2\\cos{\\theta} + 3 = 5 \\]\n\\[ 2\\cos{\\theta} = 2 \\]\n\\[ \\cos{\\theta} = 1 \\]\n解得：\n\\[ \\theta = 0^\\circ, 360^\\circ, 720^\\circ, \\ldots \\] （即所有整数倍的180°）\n\n### 3. 使用余弦定理\n**问题:** 在△ABC中，已知a=5，b=7，角C=60°，求边c。\n**解答:**\n使用余弦定理：\n\\[ c^2 = a^2 + b^2 - 2ab\\cos{C} \\]\n\\[ c^2 = 5^2 + 7^2 - 2 \\times 5 \\times 7 \\times \\cos{60^\\circ} \\]\n\\[ c^2 = 25 + 49 - 70 \\times 0.5 \\]\n\\[ c^2 = 74 - 35 = 39 \\]\n\\[ c = \\sqrt{39} \\approx 6.245 \\]\n\n### 4. 正弦定理\n**问题:** 在△ABC中，已知a=7，b=10，角A=30°，求角B。\n**解答:**\n使用正弦定理：\n\\[ \\frac{a}{\\sin{A}} = \\frac{b}{\\sin{B}} \\]\n\\[ \\frac{7}{0.5} = \\frac{10}{\\sin{B}} \\]\n\\[ 14 = \\frac{10}{\\sin{B}} \\]\n\\[ \\sin{B} = \\frac{10}{14} = \\frac{5}{7} \\approx 0.7143 \\]\n因此，角B ≈ arcsin(0.7143) ≈ 45.6° 或 134.4°\n\n### 5. 解三角形问题\n**问题:** 在△ABC中，已知a=3，b=4，c=5，求角度A。\n**解答:**\n观察到三角形为直角三角形（3² + 4² = 5²），因此：\n\\[ \\cos{A} = \\frac{b^2 + c^2 - a^2}{2bc} = \\frac{0}{24} = 0 \\]\n所以，角A = 90°。\n\n如果你有具体的余弦相关问题或方程，请告诉我，我可以进一步解答！', additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2025-04-04T13:37:05.8507333Z', 'done': True, 'done_reason': 'stop', 'total_duration': 47700315400, 'load_duration': 35743800, 'prompt_eval_count': 7, 'prompt_eval_duration': 61056400, 'eval_count': 701, 'eval_duration': 47602490500, 'message': Message(role='assistant', content='', images=None, tool_calls=None)}, id='run-d4ad0b08-1066-4daf-ad4a-f387a1bd71a6-0', usage_metadata={'input_tokens': 7, 'output_tokens': 701, 'total_tokens': 708})

# %%
from langchain_community.llms import Ollama
llm_deepseek = Ollama(base_url='http://localhost:11434', model='deepseek-r1:1.5b', temperature=0.1)

# %%
llm_deepseek.invoke("你好")
# Out:
# '<think>\n\n</think>\n\n你好！很高兴见到你，有什么我可以帮忙的吗？无论是学习、工作还是生活中的问题，都可以告诉我哦！😊'

# %%
from langchain_ollama import OllamaLLM

model = OllamaLLM(base_url='http://localhost:11434', model='deepseek-r1:1.5b',temperature=0.1)
model.invoke("你好")
# Out:
# '<think>\n\n</think>\n\n你好！很高兴见到你，有什么我可以帮忙的吗？无论是学习、工作还是生活中的问题，都可以告诉我哦！😊'
